# %% [markdown]
# <a href="https://colab.research.google.com/github/jesteenaec2529-collab/s2codebase/blob/main/Experiment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Experiment No :3**
#
# Evaluating gradient of a `scalar` field and visualize

# %% [markdown]
# **case** find the gradient of the scalar field $f=x^2+y^2+z^2$ and plot the gradient field.

# %% [markdown]
# ##**Solution**
#
# Evaluating the gradient of the scalar field

# %%
import sympy as sp

#Define the symbols
x, y, z = sp.symbols('x y z')

#Define the scalar field
scalar_field =x**2+y**2+z**2  #Example scalar field
scalar_field
# Out:
# x**2 + y**2 + z**2

# %%
# Compute the gradient

gradient =sp.Matrix([sp.diff(scalar_field,var) for var in(x,y,z)])
print("The gradient of the scalar field is")
gradient
# Out:
# The gradient of the scalar field is
# Matrix([
# [2*x],
# [2*y],
# [2*z]])

# %% [markdown]
# ##**Ploting the gradient of the scalar field**

# %%
import numpy as np
import matplotlib.pyplot as plt

#Define a grid of points where you want to evaluate the gradient
x_vals = np.linspace(-10,10,20)
y_vals = np.linspace(-10,10,20)
z_vals = 0 # for 2D visulization in the z=0 plane

X,Y = np.meshgrid(x_vals,y_vals)

#Initialize arrays to store gradient components

u = np.zeros_like(X, dtype =float)
v = np.zeros_like(Y, dtype =float)

#Evauate the gradient at each point
for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    grad_evaluated = gradient.subs({x:X[i,j],y:Y[i,j],z:z_vals})
    u[i,j] = grad_evaluated[0]
    v[i,j] = grad_evaluated[1]


#Plot the gradient vectors using matplotlib
fig ,ax =plt.subplots()
ax.quiver(X,Y,u,v)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient of the scalar field')

plt.show()

# %% [markdown]
# ##**problem**

# %%
import sympy as sp
#Define the symbols
x,y =sp.symbols('x y')

#Define the scalar field

scalar_field1 =100*sp.exp(-(x**2+y**2)/2) #Examole scalar field
scalar_field1
# Out:
# 100*exp(-x**2/2 - y**2/2)

# %%
#compute the gradient
grad = sp.Matrix([sp.diff(scalar_field1,var) for var in(x,y)])
print("The gradient of the scalar field is")
grad
# Out:
# The gradient of the scalar field is
# Matrix([
# [-100*x*exp(-x**2/2 - y**2/2)],
# [-100*y*exp(-x**2/2 - y**2/2)]])

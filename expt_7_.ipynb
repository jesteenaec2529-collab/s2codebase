# %% [markdown]
# <a href="https://colab.research.google.com/github/jesteenaec2529-collab/s2codebase/blob/main/expt_7_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # evaluate the surface integral of the curl of the vector field $F(x,y,z)=(y,z,x)$ over the surface $S$, which is the part of the plane $z=1-x-y$ in the first octant ,using stoke's theorem
